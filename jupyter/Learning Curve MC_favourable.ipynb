# %%
import numpy as np
import sys
import os
import random
import matplotlib.pyplot as plt
import math
sys.path.append('../')
os.getcwd()


from src.GridWorld import *

# %load_ext autoreload
# %autoreload 2

# %%
grid = GridWorld(p = 0.9)

# %% [markdown]
# ## Question 2

# %%
V2,opt_pol2,epochs2 = grid.value_iteration(discount = 0.9,threshold = 0.0001)
grid.draw_value(V2)
grid.draw_deterministic_policy(np.array([np.argmax(opt_pol2[row,:]) for row in range(grid.state_size)]))

# %%
epochs2
# Out:
# 12

# %%
V2,opt_pol2,epochs2 = grid.policy_iteration(discount = 0.9,threshold = 0.00001)
grid.draw_value(V2)
grid.draw_deterministic_policy(np.array([np.argmax(opt_pol2[row,:]) for row in range(grid.state_size)]))

# %% [markdown]
# ## Question 3

# %%
repeats = 1000
episodes = 2500
acc3 = np.zeros((repeats,episodes))
for i in range(repeats):
    Q3,pol3,opt_pol3,learning3,mse3,sauc3 = grid.mc_iterative(epsilon = 1,discount = 0.9,episodes = episodes)
    acc3[i,:] = np.array(learning3)
acc3

# %%
plt.plot(np.mean(acc3,axis = 0))

# %%
plt.plot(np.std(acc3,axis = 0))
